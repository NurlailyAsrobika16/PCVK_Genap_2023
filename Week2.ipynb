# %% [markdown]
# <a href="https://colab.research.google.com/github/NurlailyAsrobika16/PCVK_Genap_2023/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Nama : Nurlaily Asrobika**
#
# **NIM : 2041720172**
#
# **Kelas / No.Absen : TI3B / 13**

# %%
from google.colab import drive

#Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #**PRAKTIKUM**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img)

# %% [markdown]
# 2. OpenCV membaca image dan menyimpan dalam channel warna BGR (Blue Green Red) Tampilkan nilai pixel dan image

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #Konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# 3. Menampilkan citra Grayscale, melakukan resizing, melakukan Flipping, Menyimpan citra hasil

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘gray’

# %%
plt.imshow(img_gray, cmap = 'gray')

# %% [markdown]
# Dari citra grayscale, selanjutnya dipilih untuk ditampilkan colormap dengan warna ‘magma’

# %%
plt.imshow(img_gray, cmap = 'magma')

# %% [markdown]
# Citra RGB di resize dalam ukuran panjang 512 dan lebar 1024

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512, 1024))
plt.imshow(img4)

# %% [markdown]
# Citra RGB ditampilkan dalam ukuran yang lebih besar dengan posisi gambar terbalik

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)
#simpan File image
#ditampilan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %% [markdown]
# Membuat bentuk Geometri 2D dari OpenCV. Diawali dengan pembuatan black image dengan tipe data int16.

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img)

# %% [markdown]
# Kemudian menambahkan bentuk persegi panjang sesuai koordinat pt1 dan pt2

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0), thickness=10)
plt.imshow(black_img)

# %% [markdown]
# Selanjutnya ditambah menambahkan bentuk persegi sesuai koordinat pt1 dan pt2 yang tertulis pada kode program.

# %%
cv.rectangle(black_img, pt1=(200,200), pt2=(300,300), color=(0,0,255), thickness=15)
plt.imshow(black_img)

# %% [markdown]
# Tahap selanjutnya ditambah menambahkan bentuk lingkaran sesuai radius yang tertulis pada kode program.

# %%
cv.circle(black_img, center=(100,100), radius=50, color=(255,0,0), thickness=8)
plt.imshow(black_img)

# %% [markdown]
# Kemudian dilakukan penambahan garis sesuai koordinat pt1 dan pt2 sebagai berikut.
# Penambahan text

# %%
cv.line(black_img,pt1=(0,0), pt2=(512,512), color=(255,255,255), thickness=5)
plt.imshow(black_img)

# %% [markdown]
# Penambahan text dengan font yang telah tertulis dengan ukuran yang sudah ditentukan.

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello', org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %% [markdown]
# Pembuatan black image kembali dilakukan dengan tipe data int32

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %% [markdown]
# Berikut adalah kode program untuk inisialisasi NumPy array dengan tipe data int32

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int16)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int16)

# %% [markdown]
# Array tersebut kemudian di reshape sebagai berikut

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yg mewakili R,G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int16)

# %% [markdown]
# Penambahan polyline pada black image kedua yang telah dibuat

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# #**Pertanyaan**
# 1. Apakah perbedaan gambar yang ditampilkan tanpa dan dengan matplotlib?
# **Jawab:** Jika gambar ditampilkan menggunakan matplotlib, maka ukuran panjang dan lebar dari gambar bisa diketahui.
#
# 2. Apakah perbedaan dan pengaruhnya pembuatan black image antara tipe data int16 dan int32?
# **Jawab :**  perbedaannya terletak pada kapasitas penyimpanan yang diberikan,dimana int16 dapat menampung kapasitas sebanyak 16 bit bilangan bulat dari nilai yang diberikan pada data, sementara int32 dapat menampung sebanyak 32 bit bilangan bulat dari nilai yang diberikan pada data. Hal ini penting diperhatikan agar bisa menempatkan memori penyimpanan dengan baik.
#
# 3. Apakah kegunaan “google.colab.patches import cv2_imshow” pada potongan kode berikut
#
# from google.colab.patches import cv2_imshow
# from skimage import io
#
# **Jawab :**  cv.imshow tidak berjalan di wilayah Google Colab maupun Jupyter Notebook, karena itulah kegunaan patches dalam modul 'google.colab.patches'  penting untuk dapat mengimpor cv2_imshow() sehingga gambar dapat ditampilkan
#
# 4. Apakah kegunaan “skimage import io” pada potongan kode soal nomor 3
# **jawab :** kegunaan dari skimage adalah untuk pemrosesan gambar, termasuk untuk membaca serta menulis jenis file gambar (JPG,PNG,JPEG) sehingga gambar yang terdapat di dalam direktori dapat ditampilkan

# %% [markdown]
# #**TUGAS**

# %% [markdown]
# **1. Dengan menggunakan figsize, perhatikan apakah ukuran image pixelnya juga berubah?**

# %% [markdown]
# berikut penggunaan figisize dengan perbesaran 10x10

# %%
img5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)

#simpan File image
#ditampilan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)
print(img5.shape)
# Out:
# (192, 263, 3)

# %% [markdown]
# penggunaan figisize dengan perbesaran 5x5

# %%
img5 = cv.cvtColor(img,cv.COLOR_BGR2RGB)

#simpan File image
#ditampilan plot dengan ukuran canvas yg lebih besar
fig = plt.figure(figsize=(5,5))
ax = fig.add_subplot(111)
ax.imshow(img5)
print(img5.shape)
# Out:
# (192, 263, 3)

# %% [markdown]
# dari pixel yang dihasilkan dapat dilihat, walaupun gambar menunjukkan perbesaran, namun ukuran pixel dari gambar tetap tidak berubah (192,263,3) jadi dapat disimpulkan bahwa penggunaan figsize pada matplotlib tidak berhubungan dengan berubah tidaknya ukuran pixel

# %% [markdown]
# **2. Tampilkan image dalam channel Red-Blue dan Green-Blue saja!**

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGRA2RGB) #Konversi channel BGR -> RGB
plt.imshow(img3)

# %% [markdown]
# TAMPILAN SETELAH DIUBAH

# %%
#mengubah image dalam chanel RED-BLUE
fig = plt.figure(figsize=(15,15))
fig.add_subplot(121)
imggb = cv.merge([img[:,:,2], img[:,:,0], img[:,:,2]])
plt.imshow(imggb)

#mengubah image dalam chanel GREEN-BLUE
fig.add_subplot(122)
imggb = cv.merge([img[:,:,0], img[:,:,2], img[:,:,2]]) 
plt.imshow(imggb)

# %% [markdown]
# **3. Tampilkan image baris ke 20-115, kolom 25-120!**

# %%
row = img[20:116, 25:121]
plt.imshow(row)

# %% [markdown]
# **4. Tampilkan image baris ke 5-30, semua kolom, channel Red saja!**

# %%
rcr = img[5:31, :, 2]
plt.imshow(rcr)

# %% [markdown]
# **5. Buat 5 kotak berbagai ukuran dan warna yang berbeda dalam satu image disarankan menggunakan bilangan acak/random!**

# %%
black_img = np.zeros(shape=(512,512,3), dtype=np.int32)
plt.imshow(black_img)

# %%
box_img = np.zeros((512, 512, 3), dtype=np.uint8)
for i in range(5):                                                  # membuat 5 kotak dengan ukuran dan warna yang berbeda
    x1, y1 = np.random.randint(0, 512), np.random.randint(0, 512)   # membuat ukuran dan posisi kotak secara acak
    x2, y2 = np.random.randint(x1, 512), np.random.randint(y1, 512)
    color = np.random.randint(0, 255, size=(3,), dtype=np.uint8).tolist() # membuat warna kotak secara acak
    cv.rectangle(box_img, (x1, y1), (x2, y2), color, thickness=-1)        # membuat kotak pada gambar utama

plt.imshow(box_img)

# %% [markdown]
# **6. Tampilkan image dengan posisi terbalik!**

# %%
flipped_box = cv.flip(cv.cvtColor(box_img, cv.COLOR_BGR2RGB), 0)

fig = plt.figure(figsize = (10, 10))
ax = fig.add_subplot(111)
ax.imshow(flipped_box)

# %% [markdown]
# **7. Buat rectangle dan circle pada bagian wajah dari image foto anda saat beraktifitas (bukan pasfoto)**

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/ika.jpg')
plt.imshow(img)

# %%
me_img = img
me_img2 = cv.cvtColor(img,cv.COLOR_BGR2RGB) #Konversi channel BGR -> RGB
plt.imshow(me_img2)

# %%
fig = plt.figure(figsize=(10,10))
fig.add_subplot(121)
cv.circle(me_img2, center = (1000, 2000), radius = 1000, color = (255, 0, 0), thickness=11)
plt.imshow(me_img2)

fig.add_subplot(122)
cv.rectangle(me_img2, pt1 = (400, 1000), pt2 = (1900, 3000), color = (0, 255, 0), thickness=13)
plt.imshow(me_img2)

# %% [markdown]
# **8. Buat rectangle pada bagian sudut bawah kiri channel B pada color space RGB dari citra kitten/ lena/ mandrill/ male/ female/ couple/ sailboat/ peppers!**

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/sailboat2.jpg')
plt.imshow(img)

# %%
sailboat2 = img
sailboat_c = cv.cvtColor(img,cv.COLOR_BGR2RGB) #Konversi channel BGR -> RGB
plt.imshow(sailboat_c)

# %%
R, G, B = cv.split(sailboat_c)
height, width = B.shape[:2]

shape = cv.rectangle(B, pt1=(0, height-70), pt2=(150, height),color = (255, 0, 0), thickness= 10)
sailboat_img = cv.merge((R, G, B))
plt.imshow(sailboat_img)

# %% [markdown]
# **9.Lengkapi tulisan nama file pada file citra dari soal no.8. gunakan font, ukuran font, dan warna font yang sesuai keinginan anda.**

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(sailboat_img,text='sailboat.jpg', org=(10,175),fontFace=font,fontScale=0.7,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(sailboat_img)
